# %%
import numpy as np
import matplotlib.pyplot as plt
a = 5
f = 0.02
phase = np.pi / 3
t = np.arange(1, 100, 4)
x = a*np.sin(2*np.pi*f*t)
#plt.plot(t, x)
plt.xlabel("sample(n)")
plt.ylabel("time(t)")
plt.stem(t, x)
# Out:
# <StemContainer object of 3 artists>

# %%
Fs = 10
f = 5
sample = 10
x = np.arange(sample)
y = np.cos(2*np.pi*f*x/Fs)
# print(y)
plt.plot(x,y)
plt.show()
plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
Fs = 480
f = 10
sample = 100
x = np.arange(sample)

Fs1 = 80
f1 = 5
sample1 = 100
x1 = np.arange(sample1)

Fs2 = 1
f2 = .1
sample2 = 100
x2 = np.arange(1, 100, 4)

y = np.cos(2*np.pi*f*x/Fs)
y1 = np.cos(2*np.pi*f1*x1/Fs1)
y2 = np.cos(2*np.pi*f2*x2/Fs2)

plt.plot(x,y)
plt.plot(x1,y1)
# plt.stem(x2,y2, "r")
plt.show()
